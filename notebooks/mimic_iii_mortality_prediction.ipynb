# %% [markdown]
# # MIMIC: Mortality Prediction with ICD Hyperbolic Embedding Features
# by: Drew Wilimitis <br>
#
# **Purpose:** Test the effect of using hyperbolically embedded ICD code features in the mortality prediction problem.<br>
#
# **Outline:**
#
# Part A: Training Embeddings <br>
# 1. Build co-occurrence relations based on combinations of icd codes listed within each hospital admission <br>
# 2. Train embeddings of icd codes in poincare disk <br>
# 3. Use the co-occurrence relations and train euclidean embeddings with word2vec and GloVe algorithms <br>
# 4. Evaluate and compare embeddings with distance ratios and other metrics
#
# Part B: Clustering <br>
# 1. Fit hyperbolic k-means to poincare embeddings and compare to euclidean clustering (on poincare and euclidean embeddings) <br>
# 2. Evaluate unsupervised clustering performance and compare mortality/other variables across clusters <br>
#
# Part C: Mortality Prediction <br>
# 1. Define sensible features and pre-process data for prediction task <br>
# 2. Train models and analyze performance effect of using euclidean vs. hyperbolic embedding features <br>
#
# Note: For euclidean embeddings, reference https://arxiv.org/pdf/1804.01486.pdf <br>
#
# Note: Also compare to https://github.com/brettbj/PoincareEmbeddings

# %% [markdown]
# ## Importing Libraries and Loading Data

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
# %matplotlib inline
import networkx as nx
import sys
import os
import json

# import locally stored library
sys.path.append('/Users/drew/Desktop')
sys.path.append('/Users/drew/Desktop/vu_informatics')
from icd9 import icd9

# ignore warnings
import warnings
warnings.filterwarnings('ignore');

# display multiple outputs within a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all";

# %%
adm = pd.read_csv('data/mimic-iii/ADMISSIONS.csv')
adm.head()
adm.shape
adm[['SUBJECT_ID', 'HADM_ID', 'DIAGNOSIS']].nunique()
adm[['SUBJECT_ID', 'HADM_ID', 'DIAGNOSIS']].isna().sum()
adm['ADMISSION_TYPE'].value_counts() / adm.shape[0]
adm['HOSPITAL_EXPIRE_FLAG'].mean()
adm['HAS_CHARTEVENTS_DATA'].mean()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1      22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2      23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3      24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4      25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0       NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 1       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 2       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 3       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 4       NaN      EMERGENCY       EMERGENCY ROOM ADMIT
#
#           DISCHARGE_LOCATION INSURANCE LANGUAGE           RELIGION  \
# 0  DISC-TRAN CANCER/CHLDRN H   Private      NaN       UNOBTAINABLE
# 1           HOME HEALTH CARE  Medicare      NaN           CATHOLIC
# 2           HOME HEALTH CARE  Medicare     ENGL           CATHOLIC
# 3                       HOME   Private      NaN  PROTESTANT QUAKER
# 4                       HOME   Private      NaN       UNOBTAINABLE
#
#   MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0        MARRIED     WHITE  2196-04-09 10:06:00  2196-04-09 13:24:00
# 1        MARRIED     WHITE                  NaN                  NaN
# 2        MARRIED     WHITE                  NaN                  NaN
# 3         SINGLE     WHITE                  NaN                  NaN
# 4        MARRIED     WHITE  2160-11-02 01:01:00  2160-11-02 04:27:00
#
#                                            DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 0                            BENZODIAZEPINE OVERDOSE                     0
# 1  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 2                                         BRAIN MASS                     0
# 3                     INTERIOR MYOCARDIAL INFARCTION                     0
# 4                            ACUTE CORONARY SYNDROME                     0
#
#    HAS_CHARTEVENTS_DATA
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# (58976, 19)
# SUBJECT_ID    46520
# HADM_ID       58976
# DIAGNOSIS     15691
# dtype: int64
# SUBJECT_ID     0
# HADM_ID        0
# DIAGNOSIS     25
# dtype: int64
# EMERGENCY    0.713358
# NEWBORN      0.133325
# ELECTIVE     0.130663
# URGENT       0.022653
# Name: ADMISSION_TYPE, dtype: float64
# 0.09926071622354857
# 0.9730059685295713

# %%
icu = pd.read_csv('data/mimic-iii/ICUSTAYS.csv')
icu.head()
icu.shape
icu[['SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID']].nunique()
icu[['SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID']].isna().sum()
icu['LOS'].mean()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID DBSOURCE FIRST_CAREUNIT  \
# 0     365         268   110404      280836  carevue           MICU
# 1     366         269   106296      206613  carevue           MICU
# 2     367         270   188028      220345  carevue            CCU
# 3     368         271   173727      249196  carevue           MICU
# 4     369         272   164716      210407  carevue            CCU
#
#   LAST_CAREUNIT  FIRST_WARDID  LAST_WARDID               INTIME  \
# 0          MICU            52           52  2198-02-14 23:27:38
# 1          MICU            52           52  2170-11-05 11:05:29
# 2           CCU            57           57  2128-06-24 15:05:20
# 3          SICU            52           23  2120-08-07 23:12:42
# 4           CCU            57           57  2186-12-25 21:08:04
#
#                OUTTIME     LOS
# 0  2198-02-18 05:26:11  3.2490
# 1  2170-11-08 17:46:57  3.2788
# 2  2128-06-27 12:32:29  2.8939
# 3  2120-08-10 00:39:04  2.0600
# 4  2186-12-27 12:01:13  1.6202
# (61532, 12)
# SUBJECT_ID    46476
# HADM_ID       57786
# ICUSTAY_ID    61532
# dtype: int64
# SUBJECT_ID    0
# HADM_ID       0
# ICUSTAY_ID    0
# dtype: int64
# 4.91797158089793

# %%
ref_icd = pd.read_csv('data/mimic-iii/D_ICD_DIAGNOSES.csv')
ref_icd.head()
ref_icd.shape
icd_code_to_name = dict(zip(ref_icd.ICD9_CODE.values, ref_icd.SHORT_TITLE.values))
# Out:
#    ROW_ID ICD9_CODE               SHORT_TITLE  \
# 0     174     01166     TB pneumonia-oth test
# 1     175     01170    TB pneumothorax-unspec
# 2     176     01171   TB pneumothorax-no exam
# 3     177     01172  TB pneumothorx-exam unkn
# 4     178     01173  TB pneumothorax-micro dx
#
#                                           LONG_TITLE
# 0  Tuberculous pneumonia [any form], tubercle bac...
# 1              Tuberculous pneumothorax, unspecified
# 2  Tuberculous pneumothorax, bacteriological or h...
# 3  Tuberculous pneumothorax, bacteriological or h...
# 4  Tuberculous pneumothorax, tubercle bacilli fou...
# (14567, 4)

# %%
diag = pd.read_csv('/Users/drew/Downloads/DIAGNOSES_ICD.csv.gz', compression='gzip')
diag.head()
diag.shape
diag[['SUBJECT_ID', 'HADM_ID', 'ICD9_CODE']].nunique()
diag[['SUBJECT_ID', 'HADM_ID', 'ICD9_CODE']].isna().sum()
diag[['SUBJECT_ID', 'HADM_ID', 'ICD9_CODE']].groupby(['HADM_ID', 'SUBJECT_ID'])['ICD9_CODE'].count().mean()
diag[['SUBJECT_ID', 'ICD9_CODE']].groupby(['SUBJECT_ID'])['ICD9_CODE'].count().mean()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0    1297         109   172335      1.0     40301
# 1    1298         109   172335      2.0       486
# 2    1299         109   172335      3.0     58281
# 3    1300         109   172335      4.0      5855
# 4    1301         109   172335      5.0      4254
# (651047, 5)
# SUBJECT_ID    46520
# HADM_ID       58976
# ICD9_CODE      6984
# dtype: int64
# SUBJECT_ID     0
# HADM_ID        0
# ICD9_CODE     47
# dtype: int64
# 11.038388497015735
# 13.993981083404988

# %%
patients = pd.read_csv('/Users/drew/Desktop/vu-informatics/data/mimic-iii/PATIENTS.csv')
patients.head()
patients.shape
patients['GENDER'].value_counts() / patients.shape[0]
adm_dem = patients.merge(adm[['SUBJECT_ID', 'ADMITTIME', 'ETHNICITY']], on='SUBJECT_ID')
adm_dem.shape
adm_dem['ETHNICITY'].value_counts()[:5] / adm_dem.shape[0]
adm_dem['AGE_AT_ADMIT'] = pd.to_numeric(adm_dem['ADMITTIME'].apply(lambda x: x[:4])) - pd.to_numeric(adm_dem['DOB'].apply(lambda x: x[:4]))
adm_dem['AGE_AT_ADMIT'].mean()
adm_dem['AGE_AT_ADMIT'].describe()
# Out:
#    ROW_ID  SUBJECT_ID GENDER                  DOB                  DOD  \
# 0     234         249      F  2075-03-13 00:00:00                  NaN
# 1     235         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2     236         251      M  2090-03-15 00:00:00                  NaN
# 3     237         252      M  2078-03-06 00:00:00                  NaN
# 4     238         253      F  2089-11-26 00:00:00                  NaN
#
#               DOD_HOSP DOD_SSN  EXPIRE_FLAG
# 0                  NaN     NaN            0
# 1  2188-11-22 00:00:00     NaN            1
# 2                  NaN     NaN            0
# 3                  NaN     NaN            0
# 4                  NaN     NaN            0
# (46520, 8)
# M    0.5615
# F    0.4385
# Name: GENDER, dtype: float64
# (58976, 10)
# WHITE                     0.695130
# BLACK/AFRICAN AMERICAN    0.092241
# UNKNOWN/NOT SPECIFIED     0.076692
# HISPANIC OR LATINO        0.028757
# OTHER                     0.025638
# Name: ETHNICITY, dtype: float64
# 64.4303954150841
# count    58976.000000
# mean        64.430395
# std         57.201559
# min          0.000000
# 25%         43.000000
# 50%         62.000000
# 75%         76.000000
# max        311.000000
# Name: AGE_AT_ADMIT, dtype: float64

# %% [markdown]
# ## Extract ICD Co-occurrence Relations and Embed in Hyperbolic Space

# %%
# store each admissions code list
icd_dict = {}

# within each admission, define edges for each combination of codes (u, v) with increasing sequential numbers
edges = []
for hadm_id in diag.HADM_ID.unique():
    icd_list = list(diag[diag.HADM_ID == hadm_id]['ICD9_CODE'].values)
    icd_dict[hadm_id] = icd_list
    for i in range(len(icd_list)-1):
        for j in range(i+1, len(icd_list)):
            if len(icd_list[i]) <= len(icd_list[j]):
                edges.append([icd_list[j], icd_list[i]])
            else:
                edges.append([icd_list[i], icd_list[j]])

# examine edges      
print(list(icd_dict.items())[0])
len(list(icd_dict.items())[0][1])
print(edges[:5])
len(edges)
# Out:
# (172335, ['40301', '486', '58281', '5855', '4254', '2762', '7100', '2767', '7243', '45829', '2875', '28521', '28529', '27541'])
# 14
# [['40301', '486'], ['58281', '40301'], ['40301', '5855'], ['40301', '4254'], ['40301', '2762']]
# 4500907

# %%
# only keep edges with number of occurrences > cutoff, optionally keep repeated occurrences of edges
from collections import Counter
edge_count = Counter(map(tuple,edges))
cutoff = 5
keep_repeats = True
final_edges = []
for k,v in edge_count.items():
    if v >= cutoff:
        if keep_repeats:
            for i in range(v):
                final_edges.append(k)
        else:
            final_edges.append(k)
print('Initial edge occurrence count quantiles: ', np.quantile(list(edge_count.values())[:1000], q=np.arange(0,1,0.1)))
print('Number of final edges: ', len(final_edges))

# define final edges as data frame
edge_df = pd.DataFrame(final_edges, columns=['u', 'v'])

# get all chapters present in icd codes
node_list = list(set(list(edge_df.u.values) + list(edge_df.v.values)))
observed_chapters = np.sort([node for node in node_list if len(node) == 3])
print('Number of unique nodes present: ', len(node_list))
print('Three digit codes present: ', observed_chapters)

# optionally add edges from each chapter to highest level, center node            
for chapter in observed_chapters:
    final_edges.append([chapter, 'ICD-9_Diagnoses'])
node_list.append('ICD-9_Diagnoses')

# save to csv
edge_df = pd.DataFrame(final_edges, columns=['u', 'v'])
edge_df.head()
edge_df.to_csv('data/mimic-iii/mortality_pred/icd_occurrence_edges.csv', index=False)
# Out:
# Initial edge occurrence count quantiles:  [  1.    2.    5.   12.   23.   38.   64.  108.  200.  485.7]
# Number of final edges:  3413754
# Number of unique nodes present:  2911
# Three digit codes present:  ['042' '075' '135' '138' '185' '193' '220' '226' '243' '261' '262' '311'
#  '317' '319' '325' '326' '340' '412' '430' '431' '436' '449' '452' '462'
#  '481' '485' '486' '490' '496' '501' '502' '514' '515' '566' '570' '585'
#  '586' '587' '591' '605' '725' '769' '920' '936' '990' 'V08']
#        u    v
# 0  40301  486
# 1  40301  486
# 2  40301  486
# 3  40301  486
# 4  40301  486

# %%
G = nx.Graph(final_edges)
print('Algebraic Connectivity: ', nx.algebraic_connectivity(G))
print('Average Clustering: ', nx.average_clustering(G))
plt.plot(nx.degree_histogram(G))
plt.title('Degree Distribution in ICD-9 Co-occurance Graph');
# Out:
# Algebraic Connectivity:  0.0
# Average Clustering:  0.7779700879112841

# %%
# examine top 10 most frequent edges
top_ix = np.array(list(edge_count.keys()))[np.argsort(list(edge_count.values()))][::-1]
freq_edges = [[icd_code_to_name[u], icd_code_to_name[v]] for u,v in top_ix[:10]]
dict(zip(map(tuple, freq_edges), [edge_count[tuple(x)] for x in top_ix[:10]]))
# Out:
# {('Crnry athrscl natve vssl', 'Hypertension NOS'): 6844,
#  ('Atrial fibrillation', 'Hypertension NOS'): 5790,
#  ('Atrial fibrillation', 'CHF NOS'): 5745,
#  ('DMII wo cmp nt st uncntr', 'Hypertension NOS'): 5051,
#  ('Crnry athrscl natve vssl', 'CHF NOS'): 4610,
#  ('Hypertension NOS', 'CHF NOS'): 4126,
#  ('Hyperlipidemia NEC/NOS', 'Hypertension NOS'): 4071,
#  ('Crnry athrscl natve vssl', 'Hyperlipidemia NEC/NOS'): 3702,
#  ('Esophageal reflux', 'Hypertension NOS'): 3209,
#  ('DMII wo cmp nt st uncntr', 'CHF NOS'): 3209}

# %%
# define a co-occurence matrix where M[i,j] gives total co-occurences between node_list i,j 
M = np.zeros((len(node_list), len(node_list)))
node_to_index = dict(zip(node_list, np.arange(len(node_list))))
for e in final_edges:
    M[node_to_index[e[0]], node_to_index[e[1]]] += 1
M.shape
sns.heatmap((M/M.max()));

# %% [markdown]
# ### Train poincare model on observed ICD relations

# %%
# import modules within repository
sys.path.append('/Users/drew/Desktop/hyperbolic-learning/utils')
sys.path.append('/Users/drew/Desktop/hyperbolic-learning/utils/poincaré_embeddings')
from embed import *

# train poincare embeddings and save output embedding coordinates
fin = 'data/mimic-iii/mortality_pred/icd_occurrence_edges.csv' # input path with stored relations
fout = 'data/mimic-iii/mortality_pred/icd_occurrence_embeddings.csv' # output path to write embedding coordinates

# call function to train gensim's poincare embedding model
train_embeddings(input_path=fin, delimiter=',', output_path=fout, epochs=20, burn_in_alpha=0.01, 
                 batch_size=20, burn_in=10, alpha=0.1, negative=20)
# Out:
# INFO:gensim.models.poincare:loading relations from train data..
# INFO:gensim.models.poincare:loaded 3413801 relations from train data, 2914 nodes
# INFO:gensim.models.poincare:training model of size 2 with 1 workers on 3413801 relations for 20 epochs and 10 burn-in epochs, using lr=0.10000 burn-in lr=0.01000 negative=20
# INFO:gensim.models.poincare:starting burn-in (10 epochs)----------------------------------------
# INFO:gensim.models.poincare:training on epoch 1, examples #9980-#10000, loss: 59.91
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.88 s, 2580.14 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #19980-#20000, loss: 57.91
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.05 s, 2466.67 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #29980-#30000, loss: 56.42
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.06 s, 2466.08 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #39980-#40000, loss: 55.09
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.02 s, 2487.79 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #49980-#50000, loss: 54.10
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.17 s, 2400.21 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #59980-#60000, loss: 53.29
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.14 s, 2417.28 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #69980-#70000, loss: 52.69
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.35 s, 2296.71 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #79980-#80000, loss: 52.01
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.05 s, 2469.53 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #89980-#90000, loss: 51.57
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.09 s, 2443.23 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #99980-#100000, loss: 51.11
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.41 s, 2266.11 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #109980-#110000, loss: 50.62
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.54 s, 2200.63 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #119980-#120000, loss: 50.21
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.84 s, 2066.52 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #129980-#130000, loss: 50.14
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.58 s, 2185.61 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #139980-#140000, loss: 49.65
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.53 s, 2205.51 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #149980-#150000, loss: 49.48
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.24 s, 2356.31 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #159980-#160000, loss: 49.45
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.29 s, 2332.56 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #169980-#170000, loss: 49.10
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.48 s, 2233.42 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #179980-#180000, loss: 48.53
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.99 s, 2507.24 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #189980-#190000, loss: 48.53
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.56 s, 2194.68 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #199980-#200000, loss: 48.25
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.79 s, 2089.68 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #209980-#210000, loss: 48.24
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.90 s, 2040.36 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #219980-#220000, loss: 48.15
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.81 s, 2079.56 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #229980-#230000, loss: 47.94
# INFO:gensim.models.poincare:time taken for 10000 examples: 5.17 s, 1935.23 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #239980-#240000, loss: 47.78
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.75 s, 2103.79 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #249980-#250000, loss: 47.66
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.39 s, 2280.02 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #259980-#260000, loss: 47.58
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.17 s, 2400.02 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #269980-#270000, loss: 47.36
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.28 s, 2334.54 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #279980-#280000, loss: 47.20
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.30 s, 2324.10 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #289980-#290000, loss: 47.14
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.23 s, 2365.53 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #299980-#300000, loss: 46.72
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.02 s, 2485.97 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #309980-#310000, loss: 46.90
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.22 s, 2372.07 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #319980-#320000, loss: 46.92
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.32 s, 2314.47 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #329980-#330000, loss: 46.65
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.26 s, 2349.97 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #339980-#340000, loss: 46.47
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.23 s, 2362.90 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #349980-#350000, loss: 46.46
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.42 s, 2264.21 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #359980-#360000, loss: 46.68
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.38 s, 2284.22 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #369980-#370000, loss: 46.47
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.30 s, 2324.72 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #379980-#380000, loss: 46.31
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.13 s, 2422.42 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #389980-#390000, loss: 46.23
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.26 s, 2345.31 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #399980-#400000, loss: 45.96
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.55 s, 2197.70 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #409980-#410000, loss: 46.03
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.33 s, 2311.55 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #419980-#420000, loss: 45.79
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.06 s, 2465.81 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #429980-#430000, loss: 45.97
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.26 s, 2346.93 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #439980-#440000, loss: 45.94
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.25 s, 2353.64 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #449980-#450000, loss: 45.87
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.16 s, 2404.36 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #459980-#460000, loss: 45.73
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.26 s, 2345.42 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #469980-#470000, loss: 45.67
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.57 s, 2188.49 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #479980-#480000, loss: 45.60
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.47 s, 2238.37 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #489980-#490000, loss: 45.58
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.13 s, 2419.02 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #499980-#500000, loss: 45.50
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.16 s, 2401.47 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #509980-#510000, loss: 45.62
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.16 s, 2403.28 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #519980-#520000, loss: 45.52
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.30 s, 2328.15 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #529980-#530000, loss: 45.39
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.10 s, 2439.26 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #539980-#540000, loss: 45.25
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.48 s, 2230.93 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #549980-#550000, loss: 45.35
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.19 s, 2389.43 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #559980-#560000, loss: 45.06
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.15 s, 2408.26 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #569980-#570000, loss: 45.43
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.11 s, 2430.64 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #579980-#580000, loss: 45.08
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.20 s, 2378.68 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #589980-#590000, loss: 44.98
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.29 s, 2332.30 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #599980-#600000, loss: 45.11
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.03 s, 2482.57 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #609980-#610000, loss: 45.18
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.07 s, 2458.80 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #619980-#620000, loss: 45.03
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.12 s, 2429.08 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #629980-#630000, loss: 44.79
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.12 s, 2427.75 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #639980-#640000, loss: 44.85
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.27 s, 2339.51 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #649980-#650000, loss: 44.68
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.41 s, 2265.87 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #659980-#660000, loss: 44.83
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.21 s, 2375.57 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #669980-#670000, loss: 44.72
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.29 s, 2330.86 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #679980-#680000, loss: 44.88
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.32 s, 2314.20 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #689980-#690000, loss: 44.74
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.58 s, 2185.34 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #699980-#700000, loss: 44.62
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.51 s, 2218.97 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #709980-#710000, loss: 44.72
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.60 s, 2175.93 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #719980-#720000, loss: 44.74
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.39 s, 2275.62 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #729980-#730000, loss: 44.68
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.17 s, 2400.93 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #739980-#740000, loss: 44.38
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.09 s, 2442.46 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #749980-#750000, loss: 44.34
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.00 s, 2498.90 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #759980-#760000, loss: 44.43
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.07 s, 2456.83 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #769980-#770000, loss: 44.52
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.11 s, 2431.34 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #779980-#780000, loss: 44.48
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.02 s, 2484.82 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #789980-#790000, loss: 44.39
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.89 s, 2568.88 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #799980-#800000, loss: 44.45
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.98 s, 2510.70 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #809980-#810000, loss: 44.30
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.90 s, 2564.55 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #819980-#820000, loss: 44.23
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.99 s, 2508.78 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #829980-#830000, loss: 44.06
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.07 s, 2457.67 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #839980-#840000, loss: 44.02
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.88 s, 2576.13 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #849980-#850000, loss: 44.15
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.97 s, 2522.01 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #859980-#860000, loss: 44.32
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.88 s, 2577.81 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #869980-#870000, loss: 44.05
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.86 s, 2590.79 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #879980-#880000, loss: 44.05
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.94 s, 2537.71 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #889980-#890000, loss: 44.26
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.85 s, 2594.45 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #899980-#900000, loss: 43.81
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.94 s, 2537.15 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #909980-#910000, loss: 44.11
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.93 s, 2541.59 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #919980-#920000, loss: 44.11
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.95 s, 2533.07 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #929980-#930000, loss: 43.94
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.95 s, 2531.21 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #939980-#940000, loss: 43.94
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.01 s, 2491.38 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #949980-#950000, loss: 43.99
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.84 s, 2601.47 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #959980-#960000, loss: 43.89
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.85 s, 2595.69 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #969980-#970000, loss: 43.99
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.15 s, 2408.23 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #979980-#980000, loss: 43.97
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.81 s, 2624.97 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #989980-#990000, loss: 43.70
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.91 s, 2555.32 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #999980-#1000000, loss: 43.82
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.96 s, 2526.83 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1009980-#1010000, loss: 43.76
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.85 s, 2596.42 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1019980-#1020000, loss: 43.77
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.94 s, 2538.87 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1029980-#1030000, loss: 43.79
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.94 s, 2538.24 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1039980-#1040000, loss: 43.63
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.85 s, 2599.85 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1049980-#1050000, loss: 43.62
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.89 s, 2570.26 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1059980-#1060000, loss: 43.55
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.88 s, 2574.09 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1069980-#1070000, loss: 43.59
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.92 s, 2550.83 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1079980-#1080000, loss: 43.44
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.95 s, 2528.82 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1089980-#1090000, loss: 43.62
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.95 s, 2531.24 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1099980-#1100000, loss: 43.41
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.87 s, 2586.56 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1109980-#1110000, loss: 43.19
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.88 s, 2577.01 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1119980-#1120000, loss: 43.63
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.92 s, 2549.10 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1129980-#1130000, loss: 43.77
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.94 s, 2538.06 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1139980-#1140000, loss: 43.29
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.07 s, 2459.76 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1149980-#1150000, loss: 43.54
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.96 s, 2522.48 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1159980-#1160000, loss: 43.15
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.95 s, 2533.02 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1169980-#1170000, loss: 43.39
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.90 s, 2563.25 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1179980-#1180000, loss: 43.20
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.85 s, 2595.00 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1189980-#1190000, loss: 43.27
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.82 s, 2621.12 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1199980-#1200000, loss: 43.57
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.85 s, 2599.57 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1209980-#1210000, loss: 43.43
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.87 s, 2584.99 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1219980-#1220000, loss: 43.15
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.82 s, 2616.98 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1229980-#1230000, loss: 43.31
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.82 s, 2614.94 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1239980-#1240000, loss: 43.49
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.02 s, 2488.62 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1249980-#1250000, loss: 43.16
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.84 s, 2603.66 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1259980-#1260000, loss: 43.51
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.93 s, 2543.32 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1269980-#1270000, loss: 43.52
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.91 s, 2556.85 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1279980-#1280000, loss: 43.55
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.86 s, 2592.74 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1289980-#1290000, loss: 43.22
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.79 s, 2635.17 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1299980-#1300000, loss: 43.13
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.94 s, 2539.76 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1309980-#1310000, loss: 43.18
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.86 s, 2592.62 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1319980-#1320000, loss: 43.06
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.88 s, 2578.44 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1329980-#1330000, loss: 43.07
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.80 s, 2631.94 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1339980-#1340000, loss: 43.07
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.98 s, 2512.07 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1349980-#1350000, loss: 43.20
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.87 s, 2583.08 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1359980-#1360000, loss: 43.18
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.91 s, 2555.24 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1369980-#1370000, loss: 43.13
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.82 s, 2614.43 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1379980-#1380000, loss: 43.08
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.91 s, 2555.18 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1389980-#1390000, loss: 42.98
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.98 s, 2511.73 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1399980-#1400000, loss: 42.91
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.90 s, 2567.08 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1409980-#1410000, loss: 43.19
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.80 s, 2633.10 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1419980-#1420000, loss: 43.11
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.00 s, 2501.60 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1429980-#1430000, loss: 42.89
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.87 s, 2583.92 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1439980-#1440000, loss: 42.94
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.93 s, 2547.54 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1449980-#1450000, loss: 43.35
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.95 s, 2531.85 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1459980-#1460000, loss: 42.74
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.96 s, 2522.68 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1469980-#1470000, loss: 43.00
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.87 s, 2582.00 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1479980-#1480000, loss: 42.95
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.97 s, 2519.07 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1489980-#1490000, loss: 42.94
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.81 s, 2621.55 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1499980-#1500000, loss: 42.88
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.80 s, 2629.41 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1509980-#1510000, loss: 42.89
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.17 s, 2399.13 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1519980-#1520000, loss: 42.66
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.15 s, 2411.45 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1529980-#1530000, loss: 42.75
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.04 s, 2473.42 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1539980-#1540000, loss: 42.79
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.87 s, 2582.68 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1549980-#1550000, loss: 42.74
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.83 s, 2609.96 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1559980-#1560000, loss: 42.62
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.81 s, 2627.99 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1569980-#1570000, loss: 42.38
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.93 s, 2545.21 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1579980-#1580000, loss: 42.74
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.02 s, 2488.56 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1589980-#1590000, loss: 42.74
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.83 s, 2611.27 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1599980-#1600000, loss: 42.80
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.82 s, 2615.62 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1609980-#1610000, loss: 42.81
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.03 s, 2481.28 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1619980-#1620000, loss: 42.61
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.89 s, 2571.77 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1629980-#1630000, loss: 42.70
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.87 s, 2581.62 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1639980-#1640000, loss: 42.41
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.75 s, 2664.49 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1649980-#1650000, loss: 42.67
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.82 s, 2617.48 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1659980-#1660000, loss: 42.65
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.83 s, 2613.43 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1669980-#1670000, loss: 42.67
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.80 s, 2630.22 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1679980-#1680000, loss: 42.76
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.87 s, 2583.08 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1689980-#1690000, loss: 42.80
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.95 s, 2529.40 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1699980-#1700000, loss: 42.46
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.77 s, 2650.63 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1709980-#1710000, loss: 42.71
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.86 s, 2591.63 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1719980-#1720000, loss: 42.57
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.88 s, 2575.82 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1729980-#1730000, loss: 42.50
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.02 s, 2487.41 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1739980-#1740000, loss: 42.78
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.80 s, 2628.93 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1749980-#1750000, loss: 42.63
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.86 s, 2587.69 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1759980-#1760000, loss: 42.78
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.83 s, 2613.49 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1769980-#1770000, loss: 42.51
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.81 s, 2626.56 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1779980-#1780000, loss: 42.34
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.18 s, 2389.85 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1789980-#1790000, loss: 42.62
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.05 s, 2470.42 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1799980-#1800000, loss: 42.67
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.92 s, 2551.63 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1809980-#1810000, loss: 42.60
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.83 s, 2609.32 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1819980-#1820000, loss: 42.49
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.83 s, 2613.62 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1829980-#1830000, loss: 42.50
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.89 s, 2573.13 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1839980-#1840000, loss: 42.59
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.90 s, 2565.15 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1849980-#1850000, loss: 42.58
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.88 s, 2578.07 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1859980-#1860000, loss: 42.80
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.89 s, 2572.67 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1869980-#1870000, loss: 42.66
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.84 s, 2602.63 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1879980-#1880000, loss: 42.31
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.90 s, 2563.92 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1889980-#1890000, loss: 42.36
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.05 s, 2467.33 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1899980-#1900000, loss: 42.48
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.84 s, 2601.78 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1909980-#1910000, loss: 42.46
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.76 s, 2657.89 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1919980-#1920000, loss: 42.08
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.88 s, 2577.40 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1929980-#1930000, loss: 42.63
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.80 s, 2630.32 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1939980-#1940000, loss: 42.13
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.86 s, 2591.98 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1949980-#1950000, loss: 42.28
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.79 s, 2639.79 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1959980-#1960000, loss: 42.10
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.88 s, 2574.26 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1969980-#1970000, loss: 42.36
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.85 s, 2594.28 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1979980-#1980000, loss: 42.32
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.92 s, 2551.83 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1989980-#1990000, loss: 42.53
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.97 s, 2515.76 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #1999980-#2000000, loss: 42.42
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.87 s, 2586.86 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2009980-#2010000, loss: 42.05
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.84 s, 2604.20 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2019980-#2020000, loss: 42.21
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.90 s, 2561.52 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2029980-#2030000, loss: 42.30
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.89 s, 2570.02 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2039980-#2040000, loss: 42.13
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.92 s, 2548.03 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2049980-#2050000, loss: 42.27
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.80 s, 2633.81 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2059980-#2060000, loss: 42.36
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.88 s, 2577.95 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2069980-#2070000, loss: 42.05
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.85 s, 2596.18 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2079980-#2080000, loss: 42.38
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.89 s, 2570.69 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2089980-#2090000, loss: 42.23
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.03 s, 2483.70 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2099980-#2100000, loss: 42.15
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.88 s, 2575.40 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2109980-#2110000, loss: 42.04
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.93 s, 2543.35 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2119980-#2120000, loss: 41.96
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.89 s, 2573.95 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2129980-#2130000, loss: 42.48
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.82 s, 2617.53 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2139980-#2140000, loss: 42.16
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.91 s, 2558.08 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2149980-#2150000, loss: 42.29
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.94 s, 2537.38 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2159980-#2160000, loss: 42.02
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.83 s, 2613.43 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2169980-#2170000, loss: 41.96
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.79 s, 2638.79 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2179980-#2180000, loss: 42.09
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.85 s, 2600.14 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2189980-#2190000, loss: 42.19
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.92 s, 2549.84 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2199980-#2200000, loss: 42.21
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.89 s, 2569.36 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2209980-#2210000, loss: 42.05
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.85 s, 2597.49 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2219980-#2220000, loss: 41.88
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.86 s, 2589.86 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2229980-#2230000, loss: 41.99
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.99 s, 2507.80 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2239980-#2240000, loss: 42.11
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.78 s, 2643.00 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2249980-#2250000, loss: 42.30
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.94 s, 2537.73 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2259980-#2260000, loss: 42.20
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.88 s, 2579.65 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2269980-#2270000, loss: 42.01
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.89 s, 2568.63 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2279980-#2280000, loss: 42.27
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.26 s, 2347.76 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2289980-#2290000, loss: 42.16
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.27 s, 2343.86 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2299980-#2300000, loss: 42.00
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.93 s, 2546.97 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2309980-#2310000, loss: 41.72
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.56 s, 2194.46 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2319980-#2320000, loss: 42.32
# INFO:gensim.models.poincare:time taken for 10000 examples: 5.65 s, 1769.92 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2329980-#2330000, loss: 41.87
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.77 s, 2094.96 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2339980-#2340000, loss: 41.83
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.26 s, 2345.31 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2349980-#2350000, loss: 41.89
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.11 s, 2430.72 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2359980-#2360000, loss: 42.01
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.99 s, 2507.43 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2369980-#2370000, loss: 41.92
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.84 s, 2606.45 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2379980-#2380000, loss: 42.03
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.82 s, 2616.58 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2389980-#2390000, loss: 42.10
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.82 s, 2618.18 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2399980-#2400000, loss: 41.71
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.82 s, 2615.13 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2409980-#2410000, loss: 41.75
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.80 s, 2628.35 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2419980-#2420000, loss: 41.91
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.81 s, 2626.11 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2429980-#2430000, loss: 41.87
# INFO:gensim.models.poincare:time taken for 10000 examples: 117.31 s, 85.24 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2439980-#2440000, loss: 42.03
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.52 s, 2211.22 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2449980-#2450000, loss: 41.91
# INFO:gensim.models.poincare:time taken for 10000 examples: 5.67 s, 1762.65 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2459980-#2460000, loss: 41.94
# INFO:gensim.models.poincare:time taken for 10000 examples: 271.16 s, 36.88 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2469980-#2470000, loss: 41.92
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.18 s, 2391.25 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2479980-#2480000, loss: 42.02
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.10 s, 2438.25 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2489980-#2490000, loss: 41.39
# INFO:gensim.models.poincare:time taken for 10000 examples: 40.38 s, 247.63 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2499980-#2500000, loss: 41.95
# INFO:gensim.models.poincare:time taken for 10000 examples: 233.97 s, 42.74 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2509980-#2510000, loss: 41.91
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.15 s, 2407.71 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2519980-#2520000, loss: 41.79
# INFO:gensim.models.poincare:time taken for 10000 examples: 31.38 s, 318.65 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2529980-#2530000, loss: 41.75
# INFO:gensim.models.poincare:time taken for 10000 examples: 245.96 s, 40.66 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2539980-#2540000, loss: 41.34
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.31 s, 2322.59 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2549980-#2550000, loss: 42.00
# INFO:gensim.models.poincare:time taken for 10000 examples: 27.48 s, 363.93 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2559980-#2560000, loss: 41.70
# INFO:gensim.models.poincare:time taken for 10000 examples: 248.96 s, 40.17 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2569980-#2570000, loss: 41.53
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.20 s, 2382.58 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2579980-#2580000, loss: 42.08
# INFO:gensim.models.poincare:time taken for 10000 examples: 19.78 s, 505.50 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2589980-#2590000, loss: 41.97
# INFO:gensim.models.poincare:time taken for 10000 examples: 257.39 s, 38.85 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2599980-#2600000, loss: 41.64
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.28 s, 2334.56 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2609980-#2610000, loss: 41.76
# INFO:gensim.models.poincare:time taken for 10000 examples: 11.11 s, 899.97 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2619980-#2620000, loss: 41.79
# INFO:gensim.models.poincare:time taken for 10000 examples: 266.24 s, 37.56 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2629980-#2630000, loss: 41.58
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.62 s, 2166.02 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2639980-#2640000, loss: 41.46
# INFO:gensim.models.poincare:time taken for 10000 examples: 23.15 s, 432.05 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2649980-#2650000, loss: 41.80
# INFO:gensim.models.poincare:time taken for 10000 examples: 39.61 s, 252.49 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2659980-#2660000, loss: 41.72
# INFO:gensim.models.poincare:time taken for 10000 examples: 8.41 s, 1188.89 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2669980-#2670000, loss: 41.74
# INFO:gensim.models.poincare:time taken for 10000 examples: 5.96 s, 1677.19 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2679980-#2680000, loss: 41.32
# INFO:gensim.models.poincare:time taken for 10000 examples: 5.00 s, 1999.38 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2689980-#2690000, loss: 41.68
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.56 s, 2191.45 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #2699980-#2700000, loss: 41.47
# INFO:gensim.models.poincare:time taken for 10000 examples: 5.32 s, 1879.33 examples / s
# ...
# INFO:gensim.models.poincare:training on epoch 4, examples #2289980-#2290000, loss: 39.77
# INFO:gensim.models.poincare:time taken for 10000 examples: 272.09 s, 36.75 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2299980-#2300000, loss: 40.08
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.27 s, 2341.97 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2309980-#2310000, loss: 39.50
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.31 s, 2321.05 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2319980-#2320000, loss: 39.52
# INFO:gensim.models.poincare:time taken for 10000 examples: 272.17 s, 36.74 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2329980-#2330000, loss: 40.21
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.37 s, 2289.80 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2339980-#2340000, loss: 39.69
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.17 s, 2397.18 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2349980-#2350000, loss: 39.83
# INFO:gensim.models.poincare:time taken for 10000 examples: 271.97 s, 36.77 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2359980-#2360000, loss: 39.79
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.41 s, 2269.57 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2369980-#2370000, loss: 39.41
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.20 s, 2383.25 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2379980-#2380000, loss: 40.04
# INFO:gensim.models.poincare:time taken for 10000 examples: 272.05 s, 36.76 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2389980-#2390000, loss: 39.85
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.36 s, 2293.34 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2399980-#2400000, loss: 40.01
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.06 s, 2463.82 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2409980-#2410000, loss: 39.66
# INFO:gensim.models.poincare:time taken for 10000 examples: 34.28 s, 291.75 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2419980-#2420000, loss: 40.10
# INFO:gensim.models.poincare:time taken for 10000 examples: 242.01 s, 41.32 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2429980-#2430000, loss: 39.62
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.16 s, 2405.03 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2439980-#2440000, loss: 39.74
# INFO:gensim.models.poincare:time taken for 10000 examples: 29.36 s, 340.59 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2449980-#2450000, loss: 39.83
# INFO:gensim.models.poincare:time taken for 10000 examples: 247.30 s, 40.44 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2459980-#2460000, loss: 39.42
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.24 s, 2357.83 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2469980-#2470000, loss: 39.36
# INFO:gensim.models.poincare:time taken for 10000 examples: 23.29 s, 429.43 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2479980-#2480000, loss: 39.96
# INFO:gensim.models.poincare:time taken for 10000 examples: 252.99 s, 39.53 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2489980-#2490000, loss: 39.93
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.26 s, 2347.69 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2499980-#2500000, loss: 39.79
# INFO:gensim.models.poincare:time taken for 10000 examples: 16.26 s, 614.82 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2509980-#2510000, loss: 39.95
# INFO:gensim.models.poincare:time taken for 10000 examples: 259.92 s, 38.47 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2519980-#2520000, loss: 39.97
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.19 s, 2388.46 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2529980-#2530000, loss: 39.62
# INFO:gensim.models.poincare:time taken for 10000 examples: 8.82 s, 1134.35 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2539980-#2540000, loss: 39.85
# INFO:gensim.models.poincare:time taken for 10000 examples: 50.17 s, 199.33 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2549980-#2550000, loss: 39.64
# INFO:gensim.models.poincare:time taken for 10000 examples: 8.48 s, 1178.80 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2559980-#2560000, loss: 39.97
# INFO:gensim.models.poincare:time taken for 10000 examples: 211.60 s, 47.26 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2569980-#2570000, loss: 39.72
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.27 s, 2340.05 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2579980-#2580000, loss: 39.69
# INFO:gensim.models.poincare:time taken for 10000 examples: 29.54 s, 338.49 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2589980-#2590000, loss: 39.74
# INFO:gensim.models.poincare:time taken for 10000 examples: 246.85 s, 40.51 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2599980-#2600000, loss: 39.36
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.21 s, 2377.74 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2609980-#2610000, loss: 39.62
# INFO:gensim.models.poincare:time taken for 10000 examples: 21.11 s, 473.78 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2619980-#2620000, loss: 39.97
# INFO:gensim.models.poincare:time taken for 10000 examples: 255.06 s, 39.21 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2629980-#2630000, loss: 39.91
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.25 s, 2354.77 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2639980-#2640000, loss: 39.67
# INFO:gensim.models.poincare:time taken for 10000 examples: 12.95 s, 772.38 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2649980-#2650000, loss: 39.58
# INFO:gensim.models.poincare:time taken for 10000 examples: 263.26 s, 37.99 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2659980-#2660000, loss: 39.77
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.35 s, 2299.71 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2669980-#2670000, loss: 40.17
# INFO:gensim.models.poincare:time taken for 10000 examples: 10.42 s, 959.74 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2679980-#2680000, loss: 40.01
# INFO:gensim.models.poincare:time taken for 10000 examples: 266.12 s, 37.58 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2689980-#2690000, loss: 39.43
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.18 s, 2394.07 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2699980-#2700000, loss: 39.38
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.02 s, 2488.31 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2709980-#2710000, loss: 39.88
# INFO:gensim.models.poincare:time taken for 10000 examples: 168.66 s, 59.29 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2719980-#2720000, loss: 39.45
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.61 s, 2169.15 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2729980-#2730000, loss: 39.56
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.75 s, 2104.23 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2739980-#2740000, loss: 39.24
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.46 s, 2241.76 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2749980-#2750000, loss: 39.99
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.38 s, 2284.71 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2759980-#2760000, loss: 39.96
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.33 s, 2310.84 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2769980-#2770000, loss: 39.68
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.56 s, 2195.25 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2779980-#2780000, loss: 39.97
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.78 s, 2093.23 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2789980-#2790000, loss: 39.52
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.08 s, 2452.84 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2799980-#2800000, loss: 39.51
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.86 s, 2590.97 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2809980-#2810000, loss: 39.87
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.02 s, 2486.96 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2819980-#2820000, loss: 40.25
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.90 s, 2563.41 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2829980-#2830000, loss: 39.92
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.86 s, 2589.35 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2839980-#2840000, loss: 39.89
# INFO:gensim.models.poincare:time taken for 10000 examples: 3.96 s, 2527.01 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2849980-#2850000, loss: 39.73
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.36 s, 2295.59 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2859980-#2860000, loss: 39.84
# INFO:gensim.models.poincare:time taken for 10000 examples: 5.78 s, 1728.68 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2869980-#2870000, loss: 39.69
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.82 s, 2073.13 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2879980-#2880000, loss: 40.07
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.73 s, 2112.83 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2889980-#2890000, loss: 39.46
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.83 s, 2071.88 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2899980-#2900000, loss: 39.58
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.34 s, 2306.33 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2909980-#2910000, loss: 40.01
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.33 s, 2308.29 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2919980-#2920000, loss: 39.87
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.64 s, 2155.77 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2929980-#2930000, loss: 39.73
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.19 s, 2387.14 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2939980-#2940000, loss: 39.80
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.08 s, 2449.96 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2949980-#2950000, loss: 39.80
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.37 s, 2289.70 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2959980-#2960000, loss: 39.56
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.65 s, 2149.66 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2969980-#2970000, loss: 39.83
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.44 s, 2251.79 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2979980-#2980000, loss: 39.65
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.36 s, 2292.66 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #2989980-#2990000, loss: 40.02
# INFO:gensim.models.poincare:time taken for 10000 examples: 4.34 s, 2304.77 examples / s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-979721877bab> in <module>
#       9
#      10 # call function to train gensim's poincare embedding model
# ---> 11 train_embeddings(input_path=fin, delimiter=',', output_path=fout, epochs=20, burn_in_alpha=0.01,
#      12                  batch_size=20, burn_in=10, alpha=0.1, negative=20)
#
# ~/Desktop/hyperbolic-learning/utils/embed.py in train_embeddings(input_path, delimiter, output_path, size, alpha, burn_in, burn_in_alpha, workers, negative, epochs, print_every, batch_size)
#      42     model = PoincareModel(train_data=relations, size=size, alpha=alpha, burn_in=burn_in,
#      43                           burn_in_alpha=burn_in_alpha, workers=workers, negative=negative)
# ---> 44     model.train(epochs=epochs, print_every=print_every,batch_size=batch_size)
#      45
#      46     # save output vectors
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gensim/models/poincare.py in train(self, epochs, batch_size, print_every, check_gradients_every)
#     647             logger.info("starting burn-in (%d epochs)----------------------------------------", self.burn_in)
#     648             self.alpha = self.burn_in_alpha
# --> 649             self._train_batchwise(
#     650                 epochs=self.burn_in, batch_size=batch_size, print_every=print_every,
#     651                 check_gradients_every=check_gradients_every)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gensim/models/poincare.py in _train_batchwise(self, epochs, batch_size, print_every, check_gradients_every)
#     690                 batch_indices = indices[i:i + batch_size]
#     691                 relations = [self.all_relations[idx] for idx in batch_indices]
# --> 692                 result = self._train_on_batch(relations, check_gradients=check_gradients)
#     693                 avg_loss += result.loss
#     694                 if should_print:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gensim/models/poincare.py in _train_on_batch(self, relations, check_gradients)
#     543
#     544         """
# --> 545         all_negatives = self._sample_negatives_batch(relation[0] for relation in relations)
#     546         batch = self._prepare_training_batch(relations, all_negatives, check_gradients)
#     547         self._update_vectors_batch(batch)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gensim/models/poincare.py in _sample_negatives_batch(self, nodes)
#     524
#     525         """
# --> 526         all_indices = [self._sample_negatives(node) for node in nodes]
#     527         return all_indices
#     528
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gensim/models/poincare.py in <listcomp>(.0)
#     524
#     525         """
# --> 526         all_indices = [self._sample_negatives(node) for node in nodes]
#     527         return all_indices
#     528
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gensim/models/poincare.py in _sample_negatives(self, node_index)
#     314             # If number of positive relations is a significant fraction of total nodes
#     315             # subtract positively connected nodes from set of choices and sample from the remaining
# --> 316             valid_negatives = np.array(list(self.indices_set - node_relations))
#     317             probs = self._node_probabilities[valid_negatives]
#     318             probs /= probs.sum()
#
# KeyboardInterrupt:

# %%
# store code ranges for each chapter
chapters = icd9.icd9Chapters
drop_lettered_chapters = False
if drop_lettered_chapters:
    drop1 = chapters.pop('Supplementary Classification Of External Causes Of Injury And Poisoning')
    drop2 = chapters.pop('Supplementary Classification Of Factors Influencing Health Status And Contact With Health Services')
chapter_name_range = {}
for k,v in chapters.items():
    chapter_name_range[k] = v[0] + '_' + v[1]
chapter_range_name = {v:k for k,v in chapter_name_range.items()}

# define mappings between chapter name & range to integer class labels
chapter_name_label = {}
for i, k in enumerate(chapters.keys()):
    chapter_name_label[k] = i
chapter_range_label = {k:i for i, k in enumerate(chapter_range_name)}

# define chapter range start and end three digit codes
node_labels = {}
chapter_intervals = []
chapter_labels = []
for k, v in chapter_range_label.items():
    start = k[:3]
    end = k[4:]
    chapter_labels.append(v)
    chapter_intervals.append([start, end])

# assign each node to its chapter class label
for node in node_list:
    start = node[:3]
    if start[0] == '0' or start <= '139':
        node_labels[node] = 0
    elif start[0] == 'V':
        node_labels[node] = 17
    elif start[0] == 'E':
        node_labels[node] = 18
    elif start == 'ICD':
        continue
    else:
        for i, interval in enumerate(chapter_intervals):
            if start >= interval[0] and start <= interval[1]:
                node_labels[node] = i

# %%
# load embedding coordinates and prepare data for plotting in the poincare disk
emb = load_embeddings('data/mimic-iii/mortality_pred/icd_occurrence_embeddings.csv', delim=' ')
emb.head()
emb_data = np.array(emb.iloc[:, 1:3])
emb_dict = dict(zip(emb.node.values, emb_data))
edge_list = final_edges
labels = emb[emb.node != 'ICD-9_Diagnoses']['node'].apply(lambda x: node_labels[x]).reset_index(drop=True)
chapter_label_range = {v:k for k,v in chapter_range_label.items()}

# %%
# import cross library module
sys.path.append('/Users/drew/Desktop/vu-informatics/utils')
from poincare_viz_icd import *

# add labels for chapters and select only high level edges
chapter_emb = emb[emb.node.apply(lambda x: x in observed_chapters)]
chapter_emb_dict = dict(zip(chapter_emb.node.values, chapter_emb.iloc[:, 1:3].values))
chapter_edges = [e for e in edge_list if e[0] in observed_chapters or e[1] in observed_chapters]

plot_poincare_icd(emb, labels, edge_list=chapter_edges, add_labels=True, label_dict=chapter_emb_dict,
                  edge_frac=0.1, plot_frac=1, label_frac=0, legend_headers=chapter_label_range,
                  save=True, title='Learned from EHR Co-occurences');

# %% [markdown]
# ### Evaluate Hyperbolic Embeddings

# %%
# plot distance from center vs. node degree
radial_dist = []
degree_counts = []
for node in G.nodes():
    radial_dist.append(poincare_dist([0, 0], emb[emb['node'] == node].iloc[:,1:3]))
    degree_counts.append(G.degree(node))
plt.figure(figsize=(12,6))
print('correlation: ', np.abs(np.corrcoef(degree_counts, radial_dist)[0,1]))
plt.scatter(degree_counts, radial_dist);

# %%
def within_chapter_distances(chapter_nodes, embedding_dict):
    # compute all pairwise hyperbolic distances
    D = poincare_distances(np.array([embedding_dict[x] for x in chapter_nodes]))
    mean_dist = D[D>0].mean()
    std_dev = D[D>0].std()
    return [mean_dist, std_dev]

# %%
def between_chapter_distances(chapter_nodes, embedding, dist_matrix):
    # compute all pairwise hyperbolic distances
    embedding = embedding[embedding.node != 'ICD-9_Diagnoses'].reset_index(drop=True)
    in_group_indices = embedding[embedding.node.apply(lambda x: x in chapter_nodes)].index
    rows = np.arange(0, dist_matrix.shape[0])
    out_group_indices = list(set(rows).difference(in_group_indices))
    between_dists = [dist_matrix[ix, out_group_indices] for ix in in_group_indices]
    mean_dist = np.mean(between_dists)
    std_dev = np.std(between_dists)
    return [mean_dist, std_dev]

# %%
within_means = []
within_stds = []
between_means = []
between_stds = []
emb_data = np.array(list(emb_dict.values()))
D = poincare_distances(emb_data)
D_symm = D.T + D
for i in range(len(np.unique(labels))):
    chapter_nodes = emb[emb.node != 'ICD-9_Diagnoses']['node'].values[labels == i]
    within_mean, within_std = within_chapter_distances(chapter_nodes, emb_dict)
    within_means.append(within_mean)
    within_stds.append(within_std)
    between_mean, between_std = between_chapter_distances(chapter_nodes, emb, D_symm)
    between_means.append(between_mean)
    between_stds.append(between_std)
np.mean(within_means)
np.mean(within_stds)
np.mean(between_means)
np.mean(between_stds)
np.mean(within_means) / np.mean(between_means)

# %% [markdown]
# ### Train Euclidean Embeddings

# %% [markdown]
# Note: use cui2vec/R/glove_fit.R to fit GloVe embeddings with varying number of dimensions

# %%
# save data frame as co-occurrence matrix to use with GloVe (text2vec) in R
pd.DataFrame(nx.adjacency_matrix(G).todense(), index=list(G.nodes())).to_csv('data/mimic-iii/mortality_pred/icd_occur_matrix.csv')

# %%
# load embeddings
glove_2 = pd.read_csv('data/mimic-iii/mortality_pred/glove_emb_2.csv')
glove_2['Unnamed: 0'] = list(G.nodes())
glove_2.rename(columns={'Unnamed: 0': 'node'}, inplace=True)
glove_2.head()
glove_2.shape

glove_10 = pd.read_csv('data/mimic-iii/mortality_pred/glove_emb_10.csv')
glove_10['Unnamed: 0'] = list(G.nodes())
glove_10.rename(columns={'Unnamed: 0': 'node'}, inplace=True)
glove_10.head()
glove_10.shape

glove_100 = pd.read_csv('data/mimic-iii/mortality_pred/glove_emb_100.csv')
glove_100['Unnamed: 0'] = list(G.nodes())
glove_100.rename(columns={'Unnamed: 0': 'node'}, inplace=True)
glove_100.head()
glove_100.shape
# Out:
#     node        X1        X2
# 0  40301  0.072959  0.241434
# 1    486  0.033929  0.023469
# 2  58281  0.397968  0.440246
# 3   5855  0.243230  0.001619
# 4   4254  0.143737  0.043921
# (2912, 3)
#     node        X1        X2        X3        X4        X5        X6  \
# 0  40301  0.225529  0.210034  0.297220  0.167567  0.181666 -0.067529
# 1    486 -0.038294  0.059586  0.067501 -0.069599 -0.028638 -0.030173
# 2  58281  0.254651  0.435009  0.047343 -0.240237  0.386776  0.190925
# 3   5855 -0.125443 -0.447050 -0.455594  0.077367  0.117318 -0.227716
# 4   4254 -0.099124  0.074327  0.117942 -0.095616  0.121855 -0.026308
#
#          X7        X8        X9       X10
# 0  0.190856 -0.394909 -0.013458 -0.051145
# 1  0.051335  0.039690  0.024108  0.038452
# 2 -0.110365  0.403969  0.209565 -0.315361
# 3  0.241036  0.069007  0.026541  0.096755
# 4  0.015600  0.066173  0.014568 -0.129413
# (2912, 11)
#     node        X1        X2        X3        X4        X5        X6  \
# 0  40301  0.246076 -0.163092  0.187113 -0.419886  0.087278 -0.247041
# 1    486  0.028838 -0.149447  0.076668  0.147266  0.035793 -0.027597
# 2  58281 -0.019761  0.068480  0.091650  0.287598  0.252340 -0.220640
# 3   5855  0.239056 -0.345874  0.168877  0.132425  0.280265  0.267206
# 4   4254 -0.286886  0.142627 -0.070064  0.134789 -0.131317 -0.264538
#
#          X7        X8        X9  ...       X91       X92       X93       X94  \
# 0 -0.332622 -0.416252 -0.364196  ...  0.111610 -0.217349 -0.050255 -0.363898
# 1 -0.011047 -0.012884  0.041530  ... -0.123064 -0.179404 -0.150439 -0.153662
# 2  0.100836 -0.056052 -0.428704  ...  0.299836  0.014091  0.023331 -0.264018
# 3  0.426090 -0.187866 -0.260666  ... -0.135454 -0.186808 -0.182770  0.409403
# 4 -0.169140  0.049800  0.100532  ...  0.065720  0.070031 -0.118417  0.127201
#
#         X95       X96       X97       X98       X99      X100
# 0  0.159537  0.049124  0.273226 -0.014486  0.264415 -0.339484
# 1 -0.076157 -0.148236  0.147942  0.038622  0.037619  0.123962
# 2  0.198802 -0.347939 -0.324437  0.221079  0.270497 -0.085286
# 3  0.065099 -0.199538 -0.358427  0.301667 -0.198078  0.281448
# 4 -0.223965  0.301435  0.200001 -0.052080  0.254962  0.152952
#
# [5 rows x 101 columns]
# (2912, 101)

# %%
from sklearn.metrics import pairwise_distances
emb = glove_2
emb_data = np.array(glove_2.iloc[:, 1:3])
emb_dict = dict(zip(glove_2.node.values, emb_data))
within_means = []
within_stds = []
between_means = []
between_stds = []
emb_data = np.array(list(emb_dict.values()))
D = pairwise_distances(emb_data)
D_symm = D.T + D
for i in range(len(np.unique(labels))):
    chapter_nodes = emb[emb.node != 'ICD-9_Diagnoses']['node'].values[labels == i]
    within_mean, within_std = within_chapter_distances(chapter_nodes, emb_dict)
    within_means.append(within_mean)
    within_stds.append(within_std)
    between_mean, between_std = between_chapter_distances(chapter_nodes, emb, D_symm)
    between_means.append(between_mean)
    between_stds.append(between_std)
np.mean(within_means)
np.mean(within_stds)
np.mean(between_means)
np.mean(between_stds)
np.mean(within_means) / np.mean(between_means)
# Out:
# 1.05617213999967
# 0.5158026474121445
# 0.9549141023613378
# 0.4608663662207197
# 1.1060388964703092

# %%
emb = glove_10
emb_data = np.array(emb.iloc[:, 1:3])
emb_dict = dict(zip(emb.node.values, emb_data))
within_means = []
within_stds = []
between_means = []
between_stds = []
emb_data = np.array(list(emb_dict.values()))
D = pairwise_distances(emb_data)
D_symm = D.T + D
for i in range(len(np.unique(labels))):
    chapter_nodes = emb[emb.node != 'ICD-9_Diagnoses']['node'].values[labels == i]
    within_mean, within_std = within_chapter_distances(chapter_nodes, emb_dict)
    within_means.append(within_mean)
    within_stds.append(within_std)
    between_mean, between_std = between_chapter_distances(chapter_nodes, emb, D_symm)
    between_means.append(between_mean)
    between_stds.append(between_std)
np.mean(within_means)
np.mean(within_stds)
np.mean(between_means)
np.mean(between_stds)
np.mean(within_means) / np.mean(between_means)
# Out:
# 1.0724517450351896
# 0.5245278383479026
# 0.9621125495058325
# 0.464574838705821
# 1.1146842909242067

# %%
emb = glove_100
emb_data = np.array(emb.iloc[:, 1:3])
emb_dict = dict(zip(emb.node.values, emb_data))
within_means = []
within_stds = []
between_means = []
between_stds = []
emb_data = np.array(list(emb_dict.values()))
D = pairwise_distances(emb_data)
D_symm = D.T + D
for i in range(len(np.unique(labels))):
    chapter_nodes = emb[emb.node != 'ICD-9_Diagnoses']['node'].values[labels == i]
    within_mean, within_std = within_chapter_distances(chapter_nodes, emb_dict)
    within_means.append(within_mean)
    within_stds.append(within_std)
    between_mean, between_std = between_chapter_distances(chapter_nodes, emb, D_symm)
    between_means.append(between_mean)
    between_stds.append(between_std)
np.mean(within_means)
np.mean(within_stds)
np.mean(between_means)
np.mean(between_stds)
np.mean(within_means) / np.mean(between_means)
# Out:
# 1.0806251744933904
# 0.5237114651117992
# 0.9761443918048751
# 0.4693012657609822
# 1.107034147371714
